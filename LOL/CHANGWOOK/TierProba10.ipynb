# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import f1_score
import matplotlib.pyplot as plt
import joblib

# %matplotlib inline

# %%
import lolLGBM

# %% [markdown]
# DATA 불러오기

# %%
data = pd.read_csv("/Users/ichang-ug/Documents/GitHub/esports_YSAL/LOL/Data/CL10_fix.csv")

# %%
model, cl10_pred = lolLGBM.LGBMmodeling(data)
# Out:
# LGBM Accuracy:  70.24070021881839
# |   iter    |  target   | colsam... | learni... | max_depth | min_ch... | n_esti... | subsample |
# -------------------------------------------------------------------------------------------------
# | 1         | 0.6992    | 0.5336    | 0.2189    | 3.0       | 0.907     | 31.74     | 0.5462    |
# | 2         | 0.6818    | 0.349     | 0.1102    | 4.587     | 1.616     | 53.54     | 0.8426    |
# | 3         | 0.6684    | 0.6022    | 0.1595    | 4.137     | 1.368     | 31.31     | 0.71      |
# | 4         | 0.6961    | 0.6782    | 0.1023    | 5.652     | 1.345     | 33.78     | 0.6515    |
# | 5         | 0.6854    | 0.6741    | 0.1629    | 3.265     | 0.967     | 31.82     | 0.5615    |
# | 6         | 0.7041    | 0.5276    | 0.04547   | 5.92      | 2.604     | 73.03     | 0.6975    |
# | 7         | 0.6684    | 0.9334    | 0.03744   | 6.947     | 2.841     | 21.07     | 0.727     |
# ...

# %%
br10 = pd.read_csv("/Users/ichang-ug/Documents/GitHub/esports_YSAL/LOL/Data/BR10_fix.csv")
di10 = pd.read_csv("/Users/ichang-ug/Documents/GitHub/esports_YSAL/LOL/Data/DI10_fix.csv")
gl10 = pd.read_csv("/Users/ichang-ug/Documents/GitHub/esports_YSAL/LOL/Data/GL10_fix.csv")
ir10 = pd.read_csv("/Users/ichang-ug/Documents/GitHub/esports_YSAL/LOL/Data/IR10_fix.csv")
pl10 = pd.read_csv("/Users/ichang-ug/Documents/GitHub/esports_YSAL/LOL/Data/PL10_fix.csv")
si10 = pd.read_csv("/Users/ichang-ug/Documents/GitHub/esports_YSAL/LOL/Data/SI10_fix.csv")

data15 = [ir10, br10, si10, gl10, pl10 ,di10]
data_label = ["ir10", "br10","si10", "gl10", "pl10" ,"di10"]

# %%
for i,data in enumerate(data15):
    y_pred = model.predict(data.drop("blueWins", axis=1))
    accuracy = accuracy_score(data["blueWins"], y_pred)
    print(data_label[i])
    print("Accuracy: ", accuracy*100)
# Out:
# ir10
# Accuracy:  63.13131313131313
# br10
# Accuracy:  51.53061224489795
# si10
# Accuracy:  66.50246305418719
# gl10
# Accuracy:  72.13930348258707
# pl10
# Accuracy:  67.32673267326733
# di10
# Accuracy:  54.187192118226605
